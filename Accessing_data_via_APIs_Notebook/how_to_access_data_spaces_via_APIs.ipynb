# %% [markdown]
# # **How to access various geospatial data via web APIs**?
#
# #### This notebook is to train end users of AquaInfra Interactive Platform (AIP) to find and access geospatial data via web API requests from JupterNotebook environment directly.
# Additionally, this notebook gives examples to ease starting of data analysis by users after reading/access different geospatial data types from APIs. The example includes:
# *   calculating distance of point
# *   visualizing in interactive maps
# *   accessing and analysing data etc
#
# More deeper data analysis is left for subject experts/researcher.
#
# > Authors: Mohammad Imangholiloo and Ville Mäkinen,  Finnish Geospatial Research Institute, National Land Survey of Finland, Espoo, Finland
#
# Please feel free to contact us.

# %% [markdown]
# If you are interested to learn more about:
#  *   data accessing via API's in Jupyter environments such as Google Colab, please see: https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/APIs/API_tutorial.ipynb
# *    working with raster and vector files: https://colab.research.google.com/github/worldbank/OpenNightLights/blob/master/onl/tutorials/mod5_3_vector_and_raster_data.ipynb
#  *   geopandas for vector: https://colab.research.google.com/github/giswqs/geog-312/blob/main/book/geospatial/geopandas.ipynb
#  *   rasterio for raster: https://colab.research.google.com/github/giswqs/geog-312/blob/main/book/geospatial/rasterio.ipynb
#  *   interactive plotting raster and vector using leafmap in Google colab: https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/dataviz/raster_viz.ipynb

# %%
#Let us install required packages before start
# !pip install leafmap geopandas rasterio rioxarray
# Out:
# Requirement already satisfied: leafmap in /usr/local/lib/python3.12/dist-packages (0.60.1)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.12/dist-packages (0.21.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.12.45)
# Requirement already satisfied: duckdb>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from leafmap) (1.4.4)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from leafmap) (5.2.1)
# Requirement already satisfied: geojson in /usr/local/lib/python3.12/dist-packages (from leafmap) (3.2.0)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.20.0)
# Requirement already satisfied: ipyvuetify in /usr/local/lib/python3.12/dist-packages (from leafmap) (1.11.3)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap) (7.7.1)
# Requirement already satisfied: maplibre in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.3.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from leafmap) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from leafmap) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from leafmap) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap) (5.24.1)
# Requirement already satisfied: pystac-client in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.9.0)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap) (7.3.2)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.11.0)
# Requirement already satisfied: whiteboxgui in /usr/local/lib/python3.12/dist-packages (from leafmap) (2.3.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from leafmap) (2025.11.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (26.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.2)
# Requirement already satisfied: xarray<2025.12,>=2024.7.0 in /usr/local/lib/python3.12/dist-packages (from rioxarray) (2025.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap) (2025.3)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap) (0.15.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap) (4.15.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (3.0.16)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap) (0.2.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium->leafmap) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap) (3.24.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap) (4.67.3)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap) (0.20.0)
# Requirement already satisfied: ipyvue<2,>=1.7 in /usr/local/lib/python3.12/dist-packages (from ipyvuetify->leafmap) (1.12.0)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.12/dist-packages (from maplibre->leafmap) (0.3.1)
# Requirement already satisfied: pydantic>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from maplibre->leafmap) (2.12.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (11.3.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap) (9.1.4)
# Requirement already satisfied: pystac>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (1.14.3)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap) (0.2.2)
# Requirement already satisfied: whitebox in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap) (2.3.6)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (6.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium->leafmap) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->leafmap) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.4.2)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.12/dist-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (4.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->leafmap) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium->leafmap) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium->leafmap) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium->leafmap) (2.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->leafmap) (2.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->leafmap) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap) (0.8.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.30.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (7.17.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->leafmap) (0.6.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap) (4.9.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.21.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (4.12.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.4.0)

# %% [markdown]
# ### Background
# Please visit homepage of AquaInfra Interactive Platform (AIP) on https://aquainfra.dev.52north.org/ and add some keywords in the "Search for research data" bar, e.g. *river*. It will search *like google* for any data among all available data from various data providers listed in right side box. Below screenshot shows it. The search lists all found data and also suggest closest keywords. Please give yourself time to search any data of your interest and feel free to explore it.

# %% [markdown]
# Screenshot of the AIP homepage with the "river" as a search term:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **General Rules of this notebook**
# Here we have examples to provid step-by-step guide for exploring the data and find suitable URL API links for data access here in Jupyter notebook.
#
# In some places along the Notebook, you will see "**`Task`**:". It means you are expected to read and do that please.
#
# ### **Instruction**
# On the homepage, search term "*river*". Press search.
# Now, Below the search bar, it listed "*Related terms*" to your keyword and in the right side, you can see list of Data Providers from which the api looked for the term your input.
#
# Now, please scroll down a bit to select: "*Discharge data from automated river stations in Finland*".  Once the new browser tap opened the link, on right side of the page, where is written "*Title: Map view [Discharge]*" press VISIT. Once the new page is opened, on top bar it shows "*OAPIF / Collections / SYKE Discharge / Items*" click on "*SYKE Discharge*" (alternatively, remove "/items?f=html" from end of url), then at the end of page, press "*View*" button. It will show all items on map, within the given bbox on browser.
# NOTE: The opening new page or appearace of the items on map may take few second.
#
# Now, you can zoom and freely see the data. On the browser URL, you can change the last number which is 70'sth to 62 to zoom to only southen Finland. Now, copy paste the URL to below cell.
#
# Now, it is time to access the data behind the items. So, continue to next section :)

# %%
url = "https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items?bbox=-20.98937264741765,58.52406032052693,72.18937264741764,70.6380822712739"

# %% [markdown]
# Your link will look like the above example.
# Let us explain a bit what the url link contains and what each part mean?
# Let us first seperate each part by `/` sign in the url.
# `https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items?bbox=-20.98937264741765,58.52406032052693,72.18937264741764,62`
#
# So, we can see that:
# 1. `https://vm4072.kaj.pouta.csc.fi` which refers the server address
# 2. `ddas` refers to what developers gaved name
# 3. `oapif/` mean open api feature (feature is OFC term for vector files in desktop GIS world)
# 4. `collections` is the pygeoapi collection, which can contain list of items (raster or vectors etc)
# 5. `fin_sykedischarge` is the name of item that we would like to explore.
# 6. `items` tells that we looking for items inside the upper level item. We can specify which item id we like to explore.
# 7. `bbox=-20.98937264741765,58.52406032052693,72.18937264741764,62` referes to bounding box in WGS84 for the area of interest. you can change or limit it. format of bbox is minx, miny, maxx, maxy. Bound box is consisted to minx, miny, maxx, maxy in geographical coordinate system.

# %% [markdown]
# ## 1.1 **vector data** (e.g. OGC feature)

# %% [markdown]
# Now, we can get the data direclty via geopadas or via requests.get. they are both the sam, just alternatives. Let us start getting data via geopandas.

# %% [markdown]
# Now let us read it directly via geopandas code: ```gpd.read_file(url)```

# %%
import geopandas as gpd
gdf = gpd.read_file(url)

# %%
gdf.shape
# Out:
# (24, 3)

# %% [markdown]
# It reads/accesses the data using geopadas library as geopadas dataframe directly from given url. So, this war was the way to access and deliver data from API, from here onwards includes few examples to assist data analysis.
#
#
# `**NOTE**`: You may also noticed how amazing it was that we just accessed data directly via API url that we read it as a Python object (called gdf) and is ready for next steps of data analysis. Conventionally, we should have it downloaded locally and stored in your compare, then reading from local data. So, we read them directly via ```gpd.read_file(url)``` in above cell into our Notebook. Amazing 😯

# %%
# Let us see its head(first 3 rows)
gdf.head(3)
# Out:
#      id                                          discharge  \
# 0  1351  [[2026-02-19T00:00:00, 132.64], [2026-02-20T00...
# 1  1352  [[2026-02-19T00:00:00, 5.20], [2026-02-20T00:0...
# 2  1354  [[2026-02-19T00:00:00, 136.22], [2026-02-20T00...
#
#                     geometry
# 0   POINT (26.7457 67.96272)
# 1   POINT (27.74386 67.8219)
# 2  POINT (26.70608 67.84233)

# %%
#Let us see the dimention/shape of the read file
gdf.shape
# Out:
# (24, 3)

# %%
gdf_21_northFin = gdf

# %% [markdown]
# So, in above code, we read 21 item, and each one has 3 columns (as was shown in above cells print)

# %%
#look at the discharge column, show only first 3 rows
gdf["discharge"].head(3)
# Out:
# 0    [[2026-02-19T00:00:00, 132.64], [2026-02-20T00...
# 1    [[2026-02-19T00:00:00, 5.20], [2026-02-20T00:0...
# 2    [[2026-02-19T00:00:00, 136.22], [2026-02-20T00...
# Name: discharge, dtype: object

# %% [markdown]
# In above cell, we can see that the discharge value is a list of lists, and each list includes date, time, and discharge value. We can convert them to be ordinary dataframe to continue doing common analysis on it.

# %%
import pandas as pd
# Example of what ONE cell in gdf["data"] looks like:
# [
#   ['2026-01-01T00:00:00', '77.72'],
#   ['2026-01-02T00:00:00', '108.37'],
#   ['2026-01-03T00:00:00', '127.89']
# ]

# ---------------------------------------------------
# 1. Ensure the column really contains Python lists
#    (sometimes it's a string that *looks* like a list)
# ---------------------------------------------------
if isinstance(gdf["discharge"].iloc[0], str):
    gdf["discharge"] = gdf["discharge"].apply(eval)
gdf.head(3)
# Out:
#      id                                          discharge  \
# 0  1351  [[2026-02-19T00:00:00, 132.64], [2026-02-20T00...
# 1  1352  [[2026-02-19T00:00:00, 5.20], [2026-02-20T00:0...
# 2  1354  [[2026-02-19T00:00:00, 136.22], [2026-02-20T00...
#
#                     geometry
# 0   POINT (26.7457 67.96272)
# 1   POINT (27.74386 67.8219)
# 2  POINT (26.70608 67.84233)

# %%
# ---------------------------------------------------
# 2. Explode: one [time, value] pair per row
#    This is the key step that prevents "only first value", meaning geopandas.explode slipts
#    each row containing a multi-part geometry (in our case list of [time and discharge values])
#    into multiple rows with single geometries, thereby increasing the vertical size of the GeoDataFrame.
# ---------------------------------------------------
gdf_converted = gdf.explode("discharge", ignore_index=True)
gdf_converted.head(3)
# Out:
#      id                      discharge                  geometry
# 0  1351  [2026-02-19T00:00:00, 132.64]  POINT (26.7457 67.96272)
# 1  1351  [2026-02-20T00:00:00, 141.81]  POINT (26.7457 67.96272)
# 2  1351  [2026-02-21T00:00:00, 106.80]  POINT (26.7457 67.96272)

# %%
# ---------------------------------------------------
# 3. Split the pair into two columns
#    Now every row is exactly: ['time', 'value']
# ---------------------------------------------------
gdf_converted[["time", "value"]] = gdf_converted["discharge"].apply(pd.Series)
gdf_converted.head(3)
# Out:
#      id                      discharge                  geometry  \
# 0  1351  [2026-02-19T00:00:00, 132.64]  POINT (26.7457 67.96272)
# 1  1351  [2026-02-20T00:00:00, 141.81]  POINT (26.7457 67.96272)
# 2  1351  [2026-02-21T00:00:00, 106.80]  POINT (26.7457 67.96272)
#
#                   time   value
# 0  2026-02-19T00:00:00  132.64
# 1  2026-02-20T00:00:00  141.81
# 2  2026-02-21T00:00:00  106.80

# %%
# ---------------------------------------------------
# 4. Convert to correct dtypes
# ---------------------------------------------------
gdf_converted["time"] = pd.to_datetime(gdf_converted["time"])
gdf_converted["discharge_value"] = pd.to_numeric(gdf_converted["value"], errors="coerce")
gdf_converted.head(10)
# Out:
#      id                      discharge                  geometry       time  \
# 0  1351  [2026-02-19T00:00:00, 132.64]  POINT (26.7457 67.96272) 2026-02-19
# 1  1351  [2026-02-20T00:00:00, 141.81]  POINT (26.7457 67.96272) 2026-02-20
# 2  1351  [2026-02-21T00:00:00, 106.80]  POINT (26.7457 67.96272) 2026-02-21
# 3  1351  [2026-02-22T00:00:00, 124.19]  POINT (26.7457 67.96272) 2026-02-22
# 4  1351  [2026-02-23T00:00:00, 129.12]  POINT (26.7457 67.96272) 2026-02-23
# 5  1351  [2026-02-24T00:00:00, 157.06]  POINT (26.7457 67.96272) 2026-02-24
# 6  1351  [2026-02-25T00:00:00, 144.35]  POINT (26.7457 67.96272) 2026-02-25
# 7  1352    [2026-02-19T00:00:00, 5.20]  POINT (27.74386 67.8219) 2026-02-19
# 8  1352    [2026-02-20T00:00:00, 5.32]  POINT (27.74386 67.8219) 2026-02-20
# 9  1352    [2026-02-21T00:00:00, 5.27]  POINT (27.74386 67.8219) 2026-02-21
#
#     value  discharge_value
# 0  132.64           132.64
# 1  141.81           141.81
# 2  106.80           106.80
# 3  124.19           124.19
# 4  129.12           129.12
# 5  157.06           157.06
# 6  144.35           144.35
# 7    5.20             5.20
# 8    5.32             5.32
# 9    5.27             5.27

# %%
# ---------------------------------------------------
# 5. ['Optional'] if you wish, drop the original nested column
# ---------------------------------------------------
#gdf = gdf.drop(columns="data")

# %%
gdf_converted
# Out:
#        id                      discharge                   geometry  \
# 0    1351  [2026-02-19T00:00:00, 132.64]   POINT (26.7457 67.96272)
# 1    1351  [2026-02-20T00:00:00, 141.81]   POINT (26.7457 67.96272)
# 2    1351  [2026-02-21T00:00:00, 106.80]   POINT (26.7457 67.96272)
# 3    1351  [2026-02-22T00:00:00, 124.19]   POINT (26.7457 67.96272)
# 4    1351  [2026-02-23T00:00:00, 129.12]   POINT (26.7457 67.96272)
# ..    ...                            ...                        ...
# 171  3872   [2026-02-21T00:00:00, 17.03]  POINT (25.03225 67.80775)
# 172  3872   [2026-02-22T00:00:00, 17.27]  POINT (25.03225 67.80775)
# 173  3872   [2026-02-23T00:00:00, 17.27]  POINT (25.03225 67.80775)
# 174  3872   [2026-02-24T00:00:00, 17.13]  POINT (25.03225 67.80775)
# 175  3872   [2026-02-25T00:00:00, 17.10]  POINT (25.03225 67.80775)
#
#           time   value  discharge_value
# 0   2026-02-19  132.64           132.64
# 1   2026-02-20  141.81           141.81
# 2   2026-02-21  106.80           106.80
# 3   2026-02-22  124.19           124.19
# 4   2026-02-23  129.12           129.12
# ..         ...     ...              ...
# 171 2026-02-21   17.03            17.03
# 172 2026-02-22   17.27            17.27
# 173 2026-02-23   17.27            17.27
# 174 2026-02-24   17.13            17.13
# 175 2026-02-25   17.10            17.10
#
# [176 rows x 6 columns]

# %%
#select an id in gdf and paste in below line
gdf_converted_id_1351 = gdf_converted[gdf_converted.id == "1351"]
gdf_converted_id_1351
gdf_converted_id_1351.plot.line(x= "time", y= "discharge_value",figsize=(8,2), marker="o")
# Out:
# <Axes: xlabel='time'>

# %%
# plot all unique id values automatically (instead of manually selecting "1351") in seperate subplots
for uid, subset in gdf_converted.groupby("id"):
    plt.figure(figsize=(8, 2))
    plt.plot(subset["time"], subset["discharge_value"], marker="o")
    plt.title(f"ID: {uid}")
    plt.grid(True)
    plt.show()

# %%
# plot all unique id values automatically (instead of manually selecting "1351") in one big plots

plt.figure(figsize=(15, 4))

for uid in gdf_converted["id"].unique():
    subset = gdf_converted[gdf_converted["id"] == uid]
    plt.plot(subset["time"], subset["discharge_value"], marker="o", label=uid)

plt.xlabel("Time")
plt.ylabel("Discharge Value")
plt.legend(title="ID")
plt.grid(True)
plt.show()

# %%
# plot interactively on leaflet zoomable map
gdf_converted.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebd31634a3a80c6d1965c0df7b071786 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebd31634a3a80c6d1965c0df7b071786&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebd31634a3a80c6d1965c0df7b071786 = L.map(
#                 &quot;map_ebd31634a3a80c6d1965c0df7b071786&quot;,
#                 {
#                     center: [68.94202556619315, 24.658095676719505],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ebd31634a3a80c6d1965c0df7b071786);
#
#
#
#
#
#             var tile_layer_03fea693fa19b568d4846b2c10876b38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03fea693fa19b568d4846b2c10876b38.addTo(map_ebd31634a3a80c6d1965c0df7b071786);
#
#
#             map_ebd31634a3a80c6d1965c0df7b071786.fitBounds(
#                 [[67.80774858537818, 20.852176443308], [70.07630254700813, 28.464014910131006]],
#                 {}
#             );
#
#
#         function geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3 = L.geoJson(null, {
#                 onEachFeature: geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_onEachFeature,
#
#                 style: geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_styler,
#                 pointToLayer: geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_add (data) {
#             geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3
#                 .addData(data);
#         }
#             geo_json_5cf2c28fe8108b0ad52ecc1e1bbd08f3_add({&quot;bbox&quot;: [20.852176443308, 67.80774858537818, 28.464014910131006, 70.07630254700813], &quot;features&quot;: [{&quot;bbox&quot;: [26.745700884296564, 67.96272159795933, 26.745700884296564, 67.96272159795933], &quot;geometry&quot;: {&quot;coordinates&quot;: [26.745700884296564, 67.96272159795933], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;discharge&quot;: &quot;[\u00272026-

# %%
# calculate distance to the first point: i.e. gdf_converted.geometry.iloc[0]
from shapely.ops import nearest_points

# Example: distance to first point
gdf_converted["dist_to_first"] = gdf_converted.geometry.apply(lambda p: p.distance(gdf_converted.geometry.iloc[0]))
gdf_converted
# Out:
#        id                      discharge                   geometry  \
# 0    1351  [2026-02-19T00:00:00, 132.64]   POINT (26.7457 67.96272)
# 1    1351  [2026-02-20T00:00:00, 141.81]   POINT (26.7457 67.96272)
# 2    1351  [2026-02-21T00:00:00, 106.80]   POINT (26.7457 67.96272)
# 3    1351  [2026-02-22T00:00:00, 124.19]   POINT (26.7457 67.96272)
# 4    1351  [2026-02-23T00:00:00, 129.12]   POINT (26.7457 67.96272)
# ..    ...                            ...                        ...
# 171  3872   [2026-02-21T00:00:00, 17.03]  POINT (25.03225 67.80775)
# 172  3872   [2026-02-22T00:00:00, 17.27]  POINT (25.03225 67.80775)
# 173  3872   [2026-02-23T00:00:00, 17.27]  POINT (25.03225 67.80775)
# 174  3872   [2026-02-24T00:00:00, 17.13]  POINT (25.03225 67.80775)
# 175  3872   [2026-02-25T00:00:00, 17.10]  POINT (25.03225 67.80775)
#
#           time   value  discharge_value  dist_to_first
# 0   2026-02-19  132.64           132.64       0.000000
# 1   2026-02-20  141.81           141.81       0.000000
# 2   2026-02-21  106.80           106.80       0.000000
# 3   2026-02-22  124.19           124.19       0.000000
# 4   2026-02-23  129.12           129.12       0.000000
# ..         ...     ...              ...            ...
# 171 2026-02-21   17.03            17.03       1.720449
# 172 2026-02-22   17.27            17.27       1.720449
# 173 2026-02-23   17.27            17.27       1.720449
# 174 2026-02-24   17.13            17.13       1.720449
# 175 2026-02-25   17.10            17.10       1.720449
#
# [176 rows x 7 columns]

# %%
# Example: distance to a point: i.e. Point(26.7457, 67.96272)
from shapely.geometry import Point

ref_point = Point(26.7457, 67.96272)
gdf_converted["dist_to_point"] = gdf_converted.geometry.distance(ref_point)
gdf_converted.head(3)
# Out:
# /tmp/ipython-input-320/2764275024.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_converted["dist_to_point"] = gdf_converted.geometry.distance(ref_point)
#      id                      discharge                  geometry       time  \
# 0  1351  [2026-02-19T00:00:00, 132.64]  POINT (26.7457 67.96272) 2026-02-19
# 1  1351  [2026-02-20T00:00:00, 141.81]  POINT (26.7457 67.96272) 2026-02-20
# 2  1351  [2026-02-21T00:00:00, 106.80]  POINT (26.7457 67.96272) 2026-02-21
#
#     value  discharge_value  dist_to_first  dist_to_point
# 0  132.64           132.64            0.0       0.000002
# 1  141.81           141.81            0.0       0.000002
# 2  106.80           106.80            0.0       0.000002

# %%
#select only closest 5 points

# sort and select first 5
top5 = gdf_converted.sort_values("dist_to_point", ascending=True).head(5)
top5
# Out:
#      id                      discharge                  geometry       time  \
# 0  1351  [2026-02-19T00:00:00, 132.64]  POINT (26.7457 67.96272) 2026-02-19
# 1  1351  [2026-02-20T00:00:00, 141.81]  POINT (26.7457 67.96272) 2026-02-20
# 2  1351  [2026-02-21T00:00:00, 106.80]  POINT (26.7457 67.96272) 2026-02-21
# 3  1351  [2026-02-22T00:00:00, 124.19]  POINT (26.7457 67.96272) 2026-02-22
# 4  1351  [2026-02-23T00:00:00, 129.12]  POINT (26.7457 67.96272) 2026-02-23
#
#     value  discharge_value  dist_to_first  dist_to_point
# 0  132.64           132.64            0.0       0.000002
# 1  141.81           141.81            0.0       0.000002
# 2  106.80           106.80            0.0       0.000002
# 3  124.19           124.19            0.0       0.000002
# 4  129.12           129.12            0.0       0.000002

# %%
gdf_converted.columns
# Out:
# Index(['id', 'discharge', 'geometry', 'time', 'value', 'discharge_value',
#        'dist_to_first', 'dist_to_point'],
#       dtype='object')

# %%
gdf_converted.to_file('dataframe_gdf_converted.gpkg', driver='GPKG', layer='name')

# %%
# if you like to subset data of only one specific id, for example id = 1351
gdf_id_1351 = gdf_converted[gdf_converted['id'] == "1351"]
gdf_id_1351.head()
# Out:
#      id                      discharge                  geometry       time  \
# 0  1351  [2026-02-19T00:00:00, 132.64]  POINT (26.7457 67.96272) 2026-02-19
# 1  1351  [2026-02-20T00:00:00, 141.81]  POINT (26.7457 67.96272) 2026-02-20
# 2  1351  [2026-02-21T00:00:00, 106.80]  POINT (26.7457 67.96272) 2026-02-21
# 3  1351  [2026-02-22T00:00:00, 124.19]  POINT (26.7457 67.96272) 2026-02-22
# 4  1351  [2026-02-23T00:00:00, 129.12]  POINT (26.7457 67.96272) 2026-02-23
#
#     value  discharge_value  dist_to_first  dist_to_point
# 0  132.64           132.64            0.0       0.000002
# 1  141.81           141.81            0.0       0.000002
# 2  106.80           106.80            0.0       0.000002
# 3  124.19           124.19            0.0       0.000002
# 4  129.12           129.12            0.0       0.000002

# %%
# !ls -l /content/
# Out:
# total 136
# -rw-r--r-- 1 root root 135168 Feb 26 13:54 dataframe_gdf_converted.gpkg
# drwxr-xr-x 1 root root   4096 Jan 16 14:24 sample_data

# %%
# to download to your local machine run the below code OR in left menue, click on Files > find the file and Download
# read more on https://neptune.ai/blog/google-colab-dealing-with-files
from google.colab import files
files.download("/content/dataframe_gdf_converted.gpkg")

# %% [markdown]
# > **`Task`**: remove the ?bbox=-20.98937264741765,58.52406032052693,72.18937264741764,62 part from the url and run again. See that changes (e.g. shape of gdf) and why it changes?

# %% [markdown]
# > **`Task`**: Try below cell with the given new url. Just uncomment its lines, run and interpret your observations.

# %%
#url_task = "https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_admin_0_countries.geojson"
#gdf = gpd.read_file(url_task)
#gdf
###exlain what you see.

# plot it via
#gdf.explore()

# %% [markdown]
# > **`Task`**: Now that it plotted the countires, calculate areas of each polygon and add area as new column to it. (see below cell)

# %%
# Calculate the area (relevant if it is polygon)
#gdf["area_testing"] = gdf.area
#gdf

# %% [markdown]
# > **`Task`**: Now repeat the above task (accessing data, reading it, calculating area of polygons) to this webapi: https://ogcapi.laji.fi/collections/ahvenanmaa_polygons/items

# %% [markdown]
# > **`Task`**: [ ADVANCED]. You can get the features within bbox also for example by giving bbox to end of url. For example:
#
# https://ogcapi.laji.fi/collections/ahvenanmaa_polygons/items
#
#   add ```?bbox=20,60,20.01,60.01``` to its end and rerun. See if the shape of gpd changes?

# %% [markdown]
# *italicized text*> **`Task`**: Go to this example page (https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/erm_), select one of the items by  clicking on it (e.g. I selected "*EuroRegionalMap Seas*"), then scroll down on new page to see: "*items as GeoJSON (application/geo+json)*". Open that and copy its url to your above codes and try reading and plotting it.
# NOTE: Getting data from the urls may take few seconds, so please be patient.

# %% [markdown]
# ### Alternatively, via requests.get(url)
# You can read the data via http requests.get(url).

# %%
import requests
import pprint

# Get collections metadata
response = requests.get(url) ### NOTE: this is the same url from beginning
collections = response.json()
pprint.pprint(collections)
# Out:
# {'features': [{'geometry': {'coordinates': [26.745700884296564,
#                                             67.96272159795933],
#                             'type': 'Point'},
#                'id': '1351',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '132.64'],
#                                             ['2026-02-20T00:00:00', '141.81'],
#                                             ['2026-02-21T00:00:00', '106.80'],
#                                             ['2026-02-22T00:00:00', '124.19'],
#                                             ['2026-02-23T00:00:00', '129.12'],
#                                             ['2026-02-24T00:00:00', '157.06'],
#                                             ['2026-02-25T00:00:00', '144.35']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [27.743856134171185,
#                                             67.82189721435587],
#                             'type': 'Point'},
#                'id': '1352',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '5.20'],
#                                             ['2026-02-20T00:00:00', '5.32'],
#                                             ['2026-02-21T00:00:00', '5.27'],
#                                             ['2026-02-22T00:00:00', '5.26'],
#                                             ['2026-02-23T00:00:00', '5.30'],
#                                             ['2026-02-24T00:00:00', '5.27'],
#                                             ['2026-02-25T00:00:00', '5.23']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [26.706075052245755,
#                                             67.8423295205021],
#                             'type': 'Point'},
#                'id': '1354',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '136.22'],
#                                             ['2026-02-20T00:00:00', '134.34'],
#                                             ['2026-02-21T00:00:00', '105.48'],
#                                             ['2026-02-22T00:00:00', '122.22'],
#                                             ['2026-02-23T00:00:00', '131.26'],
#                                             ['2026-02-24T00:00:00', '150.85'],
#                                             ['2026-02-25T00:00:00', '142.89']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [23.752422561759822,
#                                             68.39611880366307],
#                             'type': 'Point'},
#                'id': '1373',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '1.66'],
#                                             ['2026-02-20T00:00:00', '1.66'],
#                                             ['2026-02-21T00:00:00', '1.67'],
#                                             ['2026-02-22T00:00:00', '1.67'],
#                                             ['2026-02-23T00:00:00', '1.66'],
#                                             ['2026-02-24T00:00:00', '1.66'],
#                                             ['2026-02-25T00:00:00', '1.64'],
#                                             ['2026-02-26T00:00:00', '1.65']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [24.844374139421454,
#                                             67.87863602408193],
#                             'type': 'Point'},
#                'id': '1374',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '25.69'],
#                                             ['2026-02-20T00:00:00', '25.84'],
#                                             ['2026-02-21T00:00:00', '26.57'],
#                                             ['2026-02-22T00:00:00', '26.52'],
#                                             ['2026-02-23T00:00:00', '27.27'],
#                                             ['2026-02-24T00:00:00', '28.56'],
#                                             ['2026-02-25T00:00:00', '28.96']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [20.852176443308, 68.93841531966775],
#                             'type': 'Point'},
#                'id': '1389',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '1.43'],
#                                             ['2026-02-20T00:00:00', '1.43'],
#                                             ['2026-02-21T00:00:00', '1.42'],
#                                             ['2026-02-22T00:00:00', '1.41'],
#                                             ['2026-02-23T00:00:00', '1.40'],
#                                             ['2026-02-24T00:00:00', '1.39'],
#                                             ['2026-02-25T00:00:00', '1.38'],
#                                             ['2026-02-26T00:00:00', '1.38']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [21.076432411899205,
#                                             68.88047238286207],
#                             'type': 'Point'},
#                'id': '1390',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '0.25'],
#                                             ['2026-02-20T00:00:00', '0.25'],
#                                             ['2026-02-21T00:00:00', '0.25'],
#                                             ['2026-02-22T00:00:00', '0.25'],
#                                             ['2026-02-23T00:00:00', '0.25'],
#                                             ['2026-02-24T00:00:00', '0.25'],
#                                             ['2026-02-25T00:00:00', '0.20']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [22.49458810967918,
#                                             68.44228126132305],
#                             'type': 'Point'},
#                'id': '1391',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '67.32'],
#                                             ['2026-02-20T00:00:00', '67.61'],
#                                             ['2026-02-21T00:00:00', '67.89'],
#                                             ['2026-02-22T00:00:00', '68.35'],
#                                             ['2026-02-23T00:00:00', '70.08'],
#                                             ['2026-02-24T00:00:00', '71.75'],
#                                             ['2026-02-25T00:00:00', '72.20']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [23.660142691096425,
#                                             67.94574804623024],
#                             'type': 'Point'},
#                'id': '1393',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '95.18'],
#                                             ['2026-02-20T00:00:00', '94.97'],
#                                             ['2026-02-21T00:00:00', '96.06'],
#                                             ['2026-02-22T00:00:00', '96.22'],
#                                             ['2026-02-23T00:00:00', '96.07'],
#                                             ['2026-02-24T00:00:00', '95.77'],
#                                             ['2026-02-25T00:00:00', '95.15'],
#                                             ['2026-02-26T00:00:00', '94.90']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [25.844884804717942,
#                                             69.39573097303908],
#                             'type': 'Point'},
#                'id': '1409',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '53.58'],
#                                             ['2026-02-20T00:00:00', '53.82'],
#                                             ['2026-02-21T00:00:00', '54.40'],
#                                             ['2026-02-22T00:00:00', '55.84'],
#                                             ['2026-02-23T00:00:00', '55.98'],
#                                             ['2026-02-24T00:00:00', '56.51'],
#                                             ['2026-02-25T00:00:00', '56.70']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [27.026974722340242,
#                                             69.9119920932981],
#                             'type': 'Point'},
#                'id': '1410',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '183.22'],
#                                             ['2026-02-20T00:00:00', '180.79'],
#                                             ['2026-02-21T00:00:00', '179.53'],
#                                             ['2026-02-22T00:00:00', '179.93'],
#                                             ['2026-02-23T00:00:00', '179.90'],
#                                             ['2026-02-24T00:00:00', '181.66'],
#                                             ['2026-02-25T00:00:00', '182.13']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [26.999533275676864,
#                                             69.7836621730441],
#                             'type': 'Point'},
#                'id': '1411',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '5.86'],
#                                             ['2026-02-20T00:00:00', '5.90'],
#                                             ['2026-02-21T00:00:00', '5.88'],
#                                             ['2026-02-22T00:00:00', '5.70'],
#                                             ['2026-02-23T00:00:00', '5.59'],
#                                             ['2026-02-24T00:00:00', '5.72'],
#                                             ['2026-02-25T00:00:00', '5.81'],
#                                             ['2026-02-26T00:00:00', '5.84']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [27.695117849706545,
#                                             70.07630254700813],
#                             'type': 'Point'},
#                'id': '1412',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '213.66'],
#                                             ['2026-02-20T00:00:00', '210.96'],
#                                             ['2026-02-21T00:00:00', '209.51'],
#                                             ['2026-02-22T00:00:00', '209.77'],
#                                             ['2026-02-23T00:00:00', '209.61'],
#                                             ['2026-02-24T00:00:00', '211.74'],
#                                             ['2026-02-25T00:00:00', '212.37']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [28.037848917443135,
#                                             69.50945189476661],
#                             'type': 'Point'},
#                'id': '1413',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '3.53'],
#                                             ['2026-02-20T00:00:00', '3.49'],
#                                             ['2026-02-21T00:00:00', '3.51'],
#                                             ['2026-02-22T00:00:00', '3.47'],
#                                             ['2026-02-23T00:00:00', '3.41'],
#                                             ['2026-02-24T00:00:00', '3.39'],
#                                             ['2026-02-25T00:00:00', '3.41'],
#                                             ['2026-02-26T00:00:00', '3.44']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [26.747540315959302,
#                                             68.91910626477849],
#                             'type': 'Point'},
#                'id': '1414',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '11.28'],
#                                             ['2026-02-20T00:00:00', '11.20'],
#                                             ['2026-02-21T00:00:00', '11.22'],
#                                             ['2026-02-22T00:00:00', '11.18'],
#                                             ['2026-02-23T00:00:00', '11.10'],
#                                             ['2026-02-24T00:00:00', '11.01'],
#                                             ['2026-02-25T00:00:00', '10.94']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [26.925190579507635,
#                                             68.88918786047367],
#                             'type': 'Point'},
#                'id': '1415',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '25.96'],
#                                             ['2026-02-20T00:00:00', '25.63'],
#                                             ['2026-02-21T00:00:00', '25.57'],
#                                             ['2026-02-22T00:00:00', '25.48'],
#                                             ['2026-02-23T00:00:00', '25.32'],
#                                             ['2026-02-24T00:00:00', '25.07'],
#                                             ['2026-02-25T00:00:00', '25.01'],
#                                             ['2026-02-26T00:00:00', '25.00']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [25.937968735073294,
#                                             68.44560529150176],
#                             'type': 'Point'},
#                'id': '1417',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '5.21'],
#                                             ['2026-02-20T00:00:00', '5.13'],
#                                             ['2026-02-21T00:00:00', '5.19'],
#                                             ['2026-02-22T00:00:00', '5.01'],
#                                             ['2026-02-23T00:00:00', '5.06'],
#                                             ['2026-02-24T00:00:00', '4.78'],
#                                             ['2026-02-25T00:00:00', '4.74'],
#                                             ['2026-02-26T00:00:00', '4.72']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [27.274470987976184,
#                                             68.55458821970161],
#                             'type': 'Point'},
#                'id': '1419',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '29.16'],
#                                             ['2026-02-20T00:00:00', '29.20'],
#                                             ['2026-02-21T00:00:00', '29.33'],
#                                             ['2026-02-22T00:00:00', '29.90'],
#                                             ['2026-02-23T00:00:00', '30.00'],
#                                             ['2026-02-24T00:00:00', '29.90'],
#                                             ['2026-02-25T00:00:00', '29.22'],
#                                             ['2026-02-26T00:00:00', '29.00']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [28.32489227054826,
#                                             68.85017158540144],
#                             'type': 'Point'},
#                'id': '1421',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '1.73'],
#                                             ['2026-02-20T00:00:00', '1.67'],
#                                             ['2026-02-21T00:00:00', '1.63'],
#                                             ['2026-02-22T00:00:00', '1.72'],
#                                             ['2026-02-23T00:00:00', '1.66'],
#                                             ['2026-02-24T00:00:00', '1.63'],
#                                             ['2026-02-25T00:00:00', '1.61']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [28.464014910131006,
#                                             68.46492967884741],
#                             'type': 'Point'},
#                'id': '1425',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '14.04'],
#                                             ['2026-02-20T00:00:00', '14.12'],
#                                             ['2026-02-21T00:00:00', '14.04'],
#                                             ['2026-02-22T00:00:00', '13.95'],
#                                             ['2026-02-23T00:00:00', '13.87'],
#                                             ['2026-02-24T00:00:00', '13.76'],
#                                             ['2026-02-25T00:00:00', '13.98']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [24.2838760252777,
#                                             68.02702293988027],
#                             'type': 'Point'},
#                'id': '3334',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '0.74'],
#                                             ['2026-02-20T00:00:00', '0.74'],
#                                             ['2026-02-21T00:00:00', '0.74'],
#                                             ['2026-02-22T00:00:00', '0.74'],
#                                             ['2026-02-23T00:00:00', '0.74'],
#                                             ['2026-02-24T00:00:00', '0.74'],
#                                             ['2026-02-25T00:00:00', '0.74']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [24.143092483676202,
#                                             68.02422099554131],
#                             'type': 'Point'},
#                'id': '3335',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '1.05'],
#                                             ['2026-02-20T00:00:00', '0.99'],
#                                             ['2026-02-21T00:00:00', '0.96'],
#                                             ['2026-02-22T00:00:00', '0.93'],
#                                             ['2026-02-23T00:00:00', '0.92'],
#                                             ['2026-02-24T00:00:00', '0.93'],
#                                             ['2026-02-25T00:00:00', '0.95']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [25.348492857466717,
#                                             67.92851202670222],
#                             'type': 'Point'},
#                'id': '3394',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '2.97'],
#                                             ['2026-02-20T00:00:00', '2.87'],
#                                             ['2026-02-21T00:00:00', '2.73'],
#                                             ['2026-02-22T00:00:00', '2.69'],
#                                             ['2026-02-23T00:00:00', '2.51'],
#                                             ['2026-02-24T00:00:00', '2.43'],
#                                             ['2026-02-25T00:00:00', '2.37']]},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [25.032245368268843,
#                                             67.80774858537818],
#                             'type': 'Point'},
#                'id': '3872',
#                'properties': {'discharge': [['2026-02-19T00:00:00', '16.83'],
#                                             ['2026-02-20T00:00:00', '16.95'],
#                                             ['2026-02-21T00:00:00', '17.03'],
#                                             ['2026-02-22T00:00:00', '17.27'],
#                                             ['2026-02-23T00:00:00', '17.27'],
#                                             ['2026-02-24T00:00:00', '17.13'],
#                                             ['2026-02-25T00:00:00', '17.10']]},
#                'type': 'Feature'}],
#  'links': [{'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items?f=json&bbox=-20.98937264741765,58.52406032052693,72.18937264741764,70.6380822712739',
#             'rel': 'self',
#             'title': 'This document as GeoJSON',
#             'type': 'application/geo+json'},
#            {'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items?f=jsonld&bbox=-20.98937264741765,58.52406032052693,72.18937264741764,70.6380822712739',
#             'rel': 'alternate',
#             'title': 'This document as RDF (JSON-LD)',
#             'type': 'application/ld+json'},
#            {'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items?f=html&bbox=-20.98937264741765,58.52406032052693,72.18937264741764,70.6380822712739',
#             'rel': 'alternate',
#             'title': 'This document as HTML',
#             'type': 'text/html'},
#            {'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items',
#             'rel': 'collection',
#             'title': 'SYKE Discharge',
#             'type': 'application/json'}],
#  'numberReturned': 24,
#  'timeStamp': '2026-02-26T14:00:50.746301Z',
#  'type': 'FeatureCollection'}

# %%
#accessing the first feature of the collection
collections["features"][1]
# Out:
# {'type': 'Feature',
#  'id': '1352',
#  'geometry': {'type': 'Point',
#   'coordinates': [27.743856134171185, 67.82189721435587]},
#  'properties': {'discharge': [['2026-02-19T00:00:00', '5.20'],
#    ['2026-02-20T00:00:00', '5.32'],
#    ['2026-02-21T00:00:00', '5.27'],
#    ['2026-02-22T00:00:00', '5.26'],
#    ['2026-02-23T00:00:00', '5.30'],
#    ['2026-02-24T00:00:00', '5.27'],
#    ['2026-02-25T00:00:00', '5.23']]}}

# %% [markdown]
# It is now read as geojson dictionary (list of features). One can convert it to geopandas df if needed, using the following cell:

# %%
gdf = gpd.GeoDataFrame.from_features(collections['features'], crs="EPSG:4326")

# Extract feature IDs
gdf["feature_id"] = [f.get("id") for f in collections["features"]]

print("The shape (row, column) of the file is =", gdf.shape)
gdf.head()
# Out:
# The shape (row, column) of the file is = (24, 3)
#                     geometry  \
# 0   POINT (26.7457 67.96272)
# 1   POINT (27.74386 67.8219)
# 2  POINT (26.70608 67.84233)
# 3  POINT (23.75242 68.39612)
# 4  POINT (24.84437 67.87864)
#
#                                            discharge feature_id
# 0  [[2026-02-19T00:00:00, 132.64], [2026-02-20T00...       1351
# 1  [[2026-02-19T00:00:00, 5.20], [2026-02-20T00:0...       1352
# 2  [[2026-02-19T00:00:00, 136.22], [2026-02-20T00...       1354
# 3  [[2026-02-19T00:00:00, 1.66], [2026-02-20T00:0...       1373
# 4  [[2026-02-19T00:00:00, 25.69], [2026-02-20T00:...       1374

# %%
gdf.shape
# Out:
# (24, 3)

# %%
##################### alternatively #####################
#from shapely.geometry import shape
#gdf2 = gpd.GeoDataFrame(
#    [feature["properties"] for feature in collections["features"]],
#    geometry=[shape(feature["geometry"]) for feature in collections["features"]],
#    crs="EPSG:4326")
#gdf2

# %% [markdown]
# ### **Advanced part 1:**
# You can also put the desired date range to access the data. Now, you can also zoom in to click on one of the items, then its item number will appear on top of menue after "*OAPIF / Collections / SYKE Discharge / Items *" for example it will be 1018. Now the URL will be sth like this: https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items/1018
#
# Now, you will see on the right side of the page: discharge values, date and values.
#
# Scroll down to see: Links and inside it, see
# "*This document as GeoJSON (application/geo+json)*". Now, you can see link that this: https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items/1018?f=json
# This is basically, the geojson of that file. you can read it like above.
#
#
# and put dates

# %%
https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items/1352

# %%
url_json = "https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items/1352?f=json"
gdf = gpd.read_file(url_json)
gdf.head(3)
# Out:
#      id                                          discharge         name  \
# 0  1352  [{'date': '2026-02-19', 'value': '5.20'}, {'da...  Lokka, pato
#
#                 waterareaname mainwaterareaname         lakename municipality  \
# 0  Lokan tekojärven la (bif.)          Kemijoki  Lokan tekojärvi    Sodankylä
#
#     number                  geometry
# 0  6500362  POINT (27.74386 67.8219)

# %%
gdf.discharge.values
# Out:
# array([list([{'date': '2026-02-19', 'value': '5.20'}, {'date': '2026-02-20', 'value': '5.32'}, {'date': '2026-02-21', 'value': '5.27'}, {'date': '2026-02-22', 'value': '5.26'}, {'date': '2026-02-23', 'value': '5.30'}, {'date': '2026-02-24', 'value': '5.27'}, {'date': '2026-02-25', 'value': '5.23'}])],
#       dtype=object)

# %% [markdown]
# Depending on the input desited dates, you can add it link this:
# ```
# &datetime=2025-10-01T00:00:00Z/2026-01-01T00:00:00Z
# ```
# to the end of yuor url.

# %%
url_json = "https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items/1018?f=json&datetime=2025-12-01T00:00:00Z/2026-01-31T00:00:00Z"
gdf_desireddate = gpd.read_file(url_json)
gdf_desireddate.head(3)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-320/1940633704.py in <cell line: 0>()
#       1 url_json = "https://vm4072.kaj.pouta.csc.fi/ddas/oapif/collections/fin_sykedischarge/items/1018?f=json&datetime=2025-12-01T00:00:00Z&&2026-01-31T00:00:00Z"
# ----> 2 gdf_desireddate = gpd.read_file(url_json)
#       3 gdf_desireddate.head(3)
#
# /usr/local/lib/python3.12/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     298         # all types of urls (https://github.com/geopandas/geopandas/issues/2908)
#     299         try:
# --> 300             with urllib.request.urlopen(
#     301                 Request(filename, headers={"Range": "bytes=0-1"})
#     302             ) as response:
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     else:
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#     217 def install_opener(opener):
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
#     519         for processor in self.process_response.get(protocol, []):
#     520             meth = getattr(processor, meth_name)
# --> 521             response = meth(req, response)
#     522
#     523         return response
#
# /usr/lib/python3.12/urllib/request.py in http_response(self, request, response)
#     628         # request was successfully received, understood, and accepted.
#     629         if not (200 <= code < 300):
# --> 630             response = self.parent.error(
#     631                 'http', request, response, code, msg, hdrs)
#     632
#
# /usr/lib/python3.12/urllib/request.py in error(self, proto, *args)
#     557         if http_err:
#     558             args = (dict, 'default', 'http_error_default') + orig_args
# --> 559             return self._call_chain(*args)
#     560
#     561 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.12/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     490         for handler in handlers:
#     491             func = getattr(handler, meth_name)
# --> 492             result = func(*args)
#     493             if result is not None:
#     494                 return result
#
# /usr/lib/python3.12/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     637 class HTTPDefaultErrorHandler(BaseHandler):
#     638     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     640
#     641 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 500: Internal Server Error

# %%
#Now let us see the discharge values
gdf_desireddate.discharge.values
# Out:
# array([list([{'date': '2025-12-01', 'value': '108.36'}, {'date': '2025-12-02', 'value': '84.10'}, {'date': '2025-12-03', 'value': '85.72'}, {'date': '2025-12-04', 'value': '97.86'}, {'date': '2025-12-05', 'value': '109.46'}, {'date': '2025-12-06', 'value': '105.08'}, {'date': '2025-12-07', 'value': '58.16'}, {'date': '2025-12-08', 'value': '53.71'}, {'date': '2025-12-09', 'value': '124.60'}, {'date': '2025-12-10', 'value': '132.03'}, {'date': '2025-12-11', 'value': '101.03'}, {'date': '2025-12-12', 'value': '98.75'}, {'date': '2025-12-13', 'value': '119.39'}, {'date': '2025-12-14', 'value': '107.39'}, {'date': '2025-12-15', 'value': '81.54'}, {'date': '2025-12-16', 'value': '115.02'}, {'date': '2025-12-17', 'value': '124.95'}, {'date': '2025-12-18', 'value': '128.04'}, {'date': '2025-12-19', 'value': '127.71'}, {'date': '2025-12-20', 'value': '124.70'}, {'date': '2025-12-21', 'value': '122.76'}, {'date': '2025-12-22', 'value': '131.21'}, {'date': '2025-12-23', 'value': '133.98'}, {'date': '2025-12-24', 'value': '137.58'}, {'date': '2025-12-25', 'value': '112.45'}, {'date': '2025-12-26', 'value': '105.04'}, {'date': '2025-12-27', 'value': '130.39'}, {'date': '2025-12-28', 'value': '134.71'}, {'date': '2025-12-29', 'value': '140.32'}, {'date': '2025-12-30', 'value': '133.60'}, {'date': '2025-12-31', 'value': '137.54'}, {'date': '2026-01-01', 'value': '139.81'}, {'date': '2026-01-02', 'value': '138.45'}, {'date': '2026-01-03', 'value': '129.80'}, {'date': '2026-01-04', 'value': '126.56'}, {'date': '2026-01-05', 'value': '133.58'}, {'date': '2026-01-06', 'value': '133.38'}, {'date': '2026-01-07', 'value': '130.78'}, {'date': '2026-01-08', 'value': '125.49'}, {'date': '2026-01-09', 'value': '134.35'}, {'date': '2026-01-10', 'value': '142.37'}, {'date': '2026-01-11', 'value': '127.34'}, {'date': '2026-01-12', 'value': '116.30'}, {'date': '2026-01-13', 'value': '132.15'}, {'date': '2026-01-14', 'value': '116.73'}, {'date': '2026-01-15', 'value': '112.90'}, {'date': '2026-01-16', 'value': '111.33'}, {'date': '2026-01-17', 'value': '93.48'}, {'date': '2026-01-18', 'value': '120.44'}, {'date': '2026-01-19', 'value': '139.31'}, {'date': '2026-01-20', 'value': '140.42'}, {'date': '2026-01-21', 'value': '112.15'}, {'date': '2026-01-22', 'value': '96.67'}, {'date': '2026-01-23', 'value': '101.38'}, {'date': '2026-01-24', 'value': '102.05'}, {'date': '2026-01-25', 'value': '102.24'}, {'date': '2026-01-26', 'value': '102.87'}, {'date': '2026-01-27', 'value': '110.48'}, {'date': '2026-01-28', 'value': '132.00'}, {'date': '2026-01-29', 'value': '110.08'}, {'date': '2026-01-30', 'value': '134.06'}, {'date': '2026-01-31', 'value': '127.87'}])],
#       dtype=object)

# %%
#convert NumPy array that contains a list of dictionaries to df
df_1 = pd.DataFrame(gdf_desireddate.discharge[0])
df_1.head(3)
# Out:
#          date   value
# 0  2025-12-01  108.36
# 1  2025-12-02   84.10
# 2  2025-12-03   85.72

# %%
#Checking data type of discharge value
df_1.value.dtype
# Out:
# dtype('O')

# %% [markdown]
# as it is ```dtype('O')```, we shall convert them to numeric. See below cell.

# %%
#converting data type of discharge value to numeric
df_1['value'] = pd.to_numeric(df_1['value'], errors='coerce')

#getting descriptive statistics of the discharge values using pandas.describe()
df_1.value.describe()
# Out:
# count     62.000000
# mean     117.483871
# std       19.255950
# min       53.710000
# 25%      105.657500
# 50%      123.680000
# 75%      132.120000
# max      142.370000
# Name: value, dtype: float64

# %% [markdown]
# ## 1.2 **raster data** (e.g. OGC coverage)

# %% [markdown]
# Now, you can put the term "*raster*" in the homepage. select "*Medium Resolution Vegetation Phenology and Productivity: Plant phenology index (raster 500m), Oct. 2022*" then in the righ side select in "*Protocol: image/png*" HOWEVERE, the download links for rasters may be crashing still due to technical reasons (under development). So, for now, please let us use this page:
# https://vm4072.kaj.pouta.csc.fi/ddas
#
#
# Now, click on Access data under "*Raster Access*". It will open https://vm4072.kaj.pouta.csc.fi/ddas/oapic/
# oapic means open api for coverage. Coverage is the term used by OGC for rasters.
#
# Now, under "*Collections*" press "*View the collections in this service*" which is hyperlinked. It shows list of collection. Let use for example select the first one "*CORINE Land Cover Plus [Pseudo Mercator]*". To get acces to the read data on Jupyter notebook, scroll down to the buttom of page where you see "*Coverage data as GTiff (image/tiff)*". With your mouse, right click and copy link. It will be: https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clcplus3857/coverage?f=GTiff. Now it is our url for raster. paste it to next cell and lets continue.

# %% [markdown]
# -20.98937264741765,58.52406032052693,72.18937264741764,70.6380822712739

# %%
https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?subset=x(-5158532.244133477:7158943.493688605),y(3600720.848604912:12398917.804192113)&f=html

# %%
url = 'https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?f=GTiff&subset=x(0:7158943.493688605),y(9600720.848604912:12398917.804192113)&scale-size=x(514.4000000000001),y(798.4000000000001)'

####  NEW today:  Discharge data from automated river stations in Finland > AquaINFRA Datasets  > Hydrography90m Basin [Pseudo Mercator]
#https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/h90m_basin3857/coverage?f=html

# %% [markdown]
# Now, it is time to read the raster from API to our jupyter notebook via rasterio directly.

# %%
import rasterio
from rasterio.plot import show
raster = rasterio.open(url) #, masked=True

print("rasters statsictal metadata is:", raster.meta)
# Out:
# rasters statsictal metadata is: {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': 255.0, 'width': 514, 'height': 798, 'count': 1, 'crs': CRS.from_wkt('PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Mercator_1SP"],PARAMETER["central_meridian",0],PARAMETER["scale_factor",1],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],EXTENSION["PROJ4","+proj=merc +a=6378137 +b=6378137 +lat_ts=0 +lon_0=0 +x_0=0 +y_0=0 +k=1 +units=m +nadgrids=@null +wktext +no_defs"],AUTHORITY["EPSG","3857"]]'), 'transform': Affine(13927.905629744368, 0.0, 0.0,
#        0.0, -3506.512475673184, 12398917.804192113)}

# %%
# we can show the raster:
show(raster)
# Out:
# <Axes: >

# %%
#if you like to read specific band
#raster2 = raster.read(1, masked=True)

# %%
#bound box of raster
raster.bounds
# Out:
# BoundingBox(left=0.0, bottom=9600720.848604912, right=7158943.493688605, top=12398917.804192113)

# %% [markdown]
# ### `TIP`: it is possible to read raster via gdal directly from url api too. See below:

# %%
#!apt-get update -qq
#!apt-get install -y gdal-bin python3-gdal

# %%
from osgeo import gdal
print(gdal.VersionInfo())
# Out:
# 3080400

# %%
ds = gdal.Open(url)

print(ds.GetProjection())
print(ds.GetGeoTransform())
print(ds.RasterXSize, ds.RasterYSize)
# Out:
# /usr/local/lib/python3.12/dist-packages/osgeo/gdal.py:312: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Mercator_1SP"],PARAMETER["central_meridian",0],PARAMETER["scale_factor",1],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],EXTENSION["PROJ4","+proj=merc +a=6378137 +b=6378137 +lat_ts=0 +lon_0=0 +x_0=0 +y_0=0 +k=1 +units=m +nadgrids=@null +wktext +no_defs"],AUTHORITY["EPSG","3857"]]
# (0.0, 13927.905629744368, 0.0, 12398917.804192113, 0.0, -3506.512475673184)
# 514 798

# %%
import numpy as np
band = ds.GetRasterBand(1)
nodata = band.GetNoDataValue()

arr = band.ReadAsArray()
arr = np.ma.masked_equal(arr, nodata)

# %%
#our rasters cooridiate refeence sytem
raster.crs
# Out:
# CRS.from_wkt('PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Mercator_1SP"],PARAMETER["central_meridian",0],PARAMETER["scale_factor",1],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],EXTENSION["PROJ4","+proj=merc +a=6378137 +b=6378137 +lat_ts=0 +lon_0=0 +x_0=0 +y_0=0 +k=1 +units=m +nadgrids=@null +wktext +no_defs"],AUTHORITY["EPSG","3857"]]')

# %%
#shap/dimentions of raster
raster.shape
# Out:
# (798, 514)

# %%
ds.RasterXSize
# Out:
# 514

# %%
#no data of raster
raster.nodata
# Out:
# 255.0

# %%
#Few statisitcs of the raster's pixel values, e.g. min, max, mean, standard deviation
raster.statistics(1) #to do stats on band 1
# Out:
# /tmp/ipython-input-320/1990654497.py:2: RasterioDeprecationWarning: statistics() will be removed in 2.0.0. Please switch to stats().
#   raster.statistics(1) #to do stats on band 1
# Statistics(min=1.0, max=254.0, mean=156.8166335092755, std=121.54755785953341)

# %% [markdown]
# Now we can plot the raster on leafmap interactive plot.
# Please zoom out to see the raster. Showing it may take few seconds, please be patient.

# %%
import leafmap
m = leafmap.Map()
m.add_cog_layer(url, name="Corine Land cover")
m
# Out:
# Map(center=[32.15494179264239, 69.33980349698753], controls=(ZoomControl(options=['position', 'zoom_in_text', …

# %%
# Let us replot and show location of plots (Section 1.1)
gdf_converted.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94422eacaeda0196eb6473fb108e9bf7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94422eacaeda0196eb6473fb108e9bf7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94422eacaeda0196eb6473fb108e9bf7 = L.map(
#                 &quot;map_94422eacaeda0196eb6473fb108e9bf7&quot;,
#                 {
#                     center: [68.94202556619315, 24.658095676719505],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_94422eacaeda0196eb6473fb108e9bf7);
#
#
#
#
#
#             var tile_layer_cbfaeac80022321b2b66b7abfa81425a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cbfaeac80022321b2b66b7abfa81425a.addTo(map_94422eacaeda0196eb6473fb108e9bf7);
#
#
#             map_94422eacaeda0196eb6473fb108e9bf7.fitBounds(
#                 [[67.80774858537818, 20.852176443308], [70.07630254700813, 28.464014910131006]],
#                 {}
#             );
#
#
#         function geo_json_19b0f758aee663ec568345ab4a9f778a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_19b0f758aee663ec568345ab4a9f778a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_19b0f758aee663ec568345ab4a9f778a_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_19b0f758aee663ec568345ab4a9f778a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_19b0f758aee663ec568345ab4a9f778a_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_19b0f758aee663ec568345ab4a9f778a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_19b0f758aee663ec568345ab4a9f778a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_19b0f758aee663ec568345ab4a9f778a = L.geoJson(null, {
#                 onEachFeature: geo_json_19b0f758aee663ec568345ab4a9f778a_onEachFeature,
#
#                 style: geo_json_19b0f758aee663ec568345ab4a9f778a_styler,
#                 pointToLayer: geo_json_19b0f758aee663ec568345ab4a9f778a_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_19b0f758aee663ec568345ab4a9f778a_add (data) {
#             geo_json_19b0f758aee663ec568345ab4a9f778a
#                 .addData(data);
#         }
#             geo_json_19b0f758aee663ec568345ab4a9f778a_add({&quot;bbox&quot;: [20.852176443308, 67.80774858537818, 28.464014910131006, 70.07630254700813], &quot;features&quot;: [{&quot;bbox&quot;: [26.745700884296564, 67.96272159795933, 26.745700884296564, 67.96272159795933], &quot;geometry&quot;: {&quot;coordinates&quot;: [26.745700884296564, 67.96272159795933], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;discharge&quot;: &quot;[\u00272026-

# %%
#Percentiles
#percentiles = np.percentile(values, [25, 50, 75, 90])
#print("25%, 50%, 75%, 90% percentiles:", percentiles)

# %% [markdown]
# ### Advanced part 2: get pixel values overlayed with vector file (discharge data) as new column, and save it.

# %%
raster.crs
# Out:
# CRS.from_wkt('PROJCS["WGS 84 / Pseudo-Mercator",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Mercator_1SP"],PARAMETER["central_meridian",0],PARAMETER["scale_factor",1],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],EXTENSION["PROJ4","+proj=merc +a=6378137 +b=6378137 +lat_ts=0 +lon_0=0 +x_0=0 +y_0=0 +k=1 +units=m +nadgrids=@null +wktext +no_defs"],AUTHORITY["EPSG","3857"]]')

# %%
gdf_21_northFin.crs #gdf_converted.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#Reprojecting crs of points to that of raster's crs
gdf_converted_reproj = gdf_21_northFin.to_crs(raster.crs)

# %%
#double checking if now their crs is the same
raster.crs == gdf_converted_reproj.crs
# Out:
# True

# %%
#Sample raster values at points
#Rasterio provides sample() for this:


# Create list of point coordinates as [(x, y), ...]
coords = [(point.x, point.y) for point in gdf_converted_reproj.geometry]

# Sample raster at each coordinate
values = [val[0] for val in raster.sample(coords)]  # val is a list per band

# Assign to GeoDataFrame
gdf_converted_reproj["raster_value"] = values

gdf_converted_reproj.head(3)
# Out:
#      id                                          discharge  \
# 0  1351  [[2026-02-19T00:00:00, 132.64], [2026-02-20T00...
# 1  1352  [[2026-02-19T00:00:00, 5.20], [2026-02-20T00:0...
# 2  1354  [[2026-02-19T00:00:00, 136.22], [2026-02-20T00...
#
#                            geometry  raster_value
# 0  POINT (2977317.803 10435928.435)             2
# 1  POINT (3088431.937 10394274.104)            10
# 2  POINT (2972906.676 10400302.152)             2

# %%
gdf_converted_reproj
# Out:
#       id                                          discharge  \
# 0   1351  [[2026-02-19T00:00:00, 132.64], [2026-02-20T00...
# 1   1352  [[2026-02-19T00:00:00, 5.20], [2026-02-20T00:0...
# 2   1354  [[2026-02-19T00:00:00, 136.22], [2026-02-20T00...
# 3   1373  [[2026-02-19T00:00:00, 1.66], [2026-02-20T00:0...
# 4   1374  [[2026-02-19T00:00:00, 25.69], [2026-02-20T00:...
# 5   1389  [[2026-02-19T00:00:00, 1.43], [2026-02-20T00:0...
# 6   1390  [[2026-02-19T00:00:00, 0.25], [2026-02-20T00:0...
# 7   1391  [[2026-02-19T00:00:00, 67.32], [2026-02-20T00:...
# 8   1393  [[2026-02-19T00:00:00, 95.18], [2026-02-20T00:...
# 9   1409  [[2026-02-19T00:00:00, 53.58], [2026-02-20T00:...
# 10  1410  [[2026-02-19T00:00:00, 183.22], [2026-02-20T00...
# 11  1411  [[2026-02-19T00:00:00, 5.86], [2026-02-20T00:0...
# 12  1412  [[2026-02-19T00:00:00, 213.66], [2026-02-20T00...
# 13  1413  [[2026-02-19T00:00:00, 3.53], [2026-02-20T00:0...
# 14  1414  [[2026-02-19T00:00:00, 11.28], [2026-02-20T00:...
# 15  1415  [[2026-02-19T00:00:00, 25.96], [2026-02-20T00:...
# 16  1417  [[2026-02-19T00:00:00, 5.21], [2026-02-20T00:0...
# 17  1419  [[2026-02-19T00:00:00, 29.16], [2026-02-20T00:...
# 18  1421  [[2026-02-19T00:00:00, 1.73], [2026-02-20T00:0...
# 19  1425  [[2026-02-19T00:00:00, 14.04], [2026-02-20T00:...
# 20  3334  [[2026-02-19T00:00:00, 0.74], [2026-02-20T00:0...
# 21  3335  [[2026-02-19T00:00:00, 1.05], [2026-02-20T00:0...
# 22  3394  [[2026-02-19T00:00:00, 2.97], [2026-02-20T00:0...
# 23  3872  [[2026-02-19T00:00:00, 16.83], [2026-02-20T00:...
#
#                             geometry  raster_value
# 0   POINT (2977317.803 10435928.435)             2
# 1   POINT (3088431.937 10394274.104)            10
# 2   POINT (2972906.676 10400302.152)             2
# 3   POINT (2644107.585 10565729.179)             2
# 4   POINT (2765663.078 10411026.527)             3
# 5   POINT (2321253.664 10731683.274)             3
# 6   POINT (2346217.724 10713758.285)            10
# 7   POINT (2504086.094 10579700.364)            10
# 8   POINT (2633835.036 10430894.462)             2
# 9   POINT (2877039.416 10874832.403)             3
# 10  POINT (3008629.064 11040131.423)             3
# 11  POINT (3005574.296 10998665.357)             6
# 12  POINT (3083006.416 11093595.891)             3
# 13  POINT (3121159.064 10910900.851)             3
# 14  POINT (2977522.568 10725704.681)             2
# 15  POINT (2997298.505 10716451.468)             2
# 16   POINT (2887401.472 10580707.49)             6
# 17  POINT (3036180.222 10613809.702)             6
# 18  POINT (3153112.584 10704403.236)             2
# 19  POINT (3168599.646 10586565.387)             2
# 20  POINT (2703268.714 10455032.243)             6
# 21  POINT (2687596.761 10454198.684)             2
# 22  POINT (2821781.317 10425786.411)             6
# 23  POINT (2786576.808 10390102.988)             2

# %%
#dropping those points which did not overlap with sample points, so their raster_value is 255 (no data)
gdf_converted_reproj_includedpoints= gdf_converted_reproj[gdf_converted_reproj.raster_value != 255]

# %%
gdf_converted_reproj_includedpoints.head(3)
# Out:
#      id                                          discharge  \
# 0  1351  [[2026-02-19T00:00:00, 132.64], [2026-02-20T00...
# 1  1352  [[2026-02-19T00:00:00, 5.20], [2026-02-20T00:0...
# 2  1354  [[2026-02-19T00:00:00, 136.22], [2026-02-20T00...
#
#                            geometry  raster_value
# 0  POINT (2977317.803 10435928.435)             2
# 1  POINT (3088431.937 10394274.104)            10
# 2  POINT (2972906.676 10400302.152)             2

# %%
#from google.colab import sheets
#sheet = sheets.InteractiveSheet(df=gdf_converted_reproj_includedpoints)

# %%
gdf_converted_reproj_includedpoints.groupby(by= "raster_value").count()
# Out:
#               id  discharge  geometry
# raster_value
# 2             10         10        10
# 3              6          6         6
# 6              5          5         5
# 10             3          3         3

# %%
gdf_converted_reproj_includedpoints.raster_value.hist(bins=256)
# Out:
# <Axes: >

# %% [markdown]
# ### Advanced part 3:
# You can read the collection s a whole and select things by adding things to the end of url. See below

# %%
# List all collections
import requests

base_url = "https://vm4072.kaj.pouta.csc.fi/ddas/oapic"

r = requests.get(f"{base_url}/collections")
collections = r.json()

for c in collections["collections"]:
    print(c["id"], "-", c["title"])
# Out:
# clc_clcplus3857-2018 - CORINE Land Cover Plus 2018 [Pseudo Mercator]
# clc_clcplus3857-2021 - CORINE Land Cover Plus 2021 [Pseudo Mercator]
# clc_clcplus3035-2018 - CORINE Land Cover Plus 2018 [LAEA]
# clc_clcplus3035-2021 - CORINE Land Cover Plus 2021 [LAEA]
# eudem3857 - EUDEM2 [Pseudo Mercator]
# eudem3035 - EUDEM2 [LAEA]
# sentinel-3-OLCI-ONNS3857 - Sentinel-3 OLCI ONNS [Pseudo Mercator]
# sentinel-3-OLCI-ONNS3035 - Sentinel-3 OLCI ONNS [LAEA]
# emodnet-biology3857 - EMODnet Biology  [Pseudo Mercator]
# fin_corine2000 - CORINE 2000
# fin_corine2006 - CORINE 2006
# fin_corine2012 - CORINE 2012
# fin_corine2018 - CORINE 2018
# h90m_basin3857 - Hydrography90m Basin [Pseudo Mercator]
# h90m_accumulation3857 - Hydrography90m Accumulation [Pseudo Mercator]
# h90m_cti3857 - Hydrography90m CTI [Pseudo Mercator]
# h90m_direction3857 - Hydrography90m Direction [Pseudo Mercator]
# h90m_outlet3857 - Hydrography90m Outlet [Pseudo Mercator]
# h90m_segment3857 - Hydrography90m Segment [Pseudo Mercator]
# h90m_subcatchment3857 - Hydrography90m Sub-catchment [Pseudo Mercator]
# h90m_basin3035 - Hydrography90m Basin [LAEA]
# h90m_accumulation3035 - Hydrography90m Accumulation [LAEA]
# h90m_cti3035 - Hydrography90m CTI [LAEA]
# h90m_direction3035 - Hydrography90m Direction [LAEA]
# h90m_outlet3035 - Hydrography90m Outlet [LAEA]
# h90m_segment3035 - Hydrography90m Segment [LAEA]
# h90m_subcatchment3035 - Hydrography90m Sub-catchment [LAEA]
# h90m_basin4326 - Hydrography90m Basin [WGS84]
# h90m_accumulation4326 - Hydrography90m Accumulation [WGS84]
# h90m_cti4326 - Hydrography90m CTI [WGS84]
# h90m_direction4326 - Hydrography90m Direction [WGS84]
# h90m_outlet4326 - Hydrography90m Outlet [WGS84]
# h90m_segment4326 - Hydrography90m Segment [WGS84]
# h90m_subcatchment4326 - Hydrography90m Sub-catchment [WGS84]

# %% [markdown]
# now, if you put the first part of name (before - ) in collection_id it can direclty read that.

# %%
collection_id = "h90m_basin4326"
base_url = "https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/h90m_basin4326/coverage?subset=x(0:4.30988358528478),y(60.75306162442881:73.70866809709719)"
#r = requests.get(base_url) ##(f"{base_url}/collections/{collection_id}")

#IF the url is vector data uncomment the following lines
#response = requests.get(base_url)
#collections = response.json()
#pprint.pprint(collections)

#IF the url is for raster data, run the following line.
#my_raster = rasterio.open(base_url)

# %% [markdown]
# > **`Task`**: Now, try other item from the collection (https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections) and repeat above steps on it.
#
# **Note**: some coleections may be links to other collection of items, if so, again select one of them until you find the "*Coverage data as GTiff (image/tiff)*" from bottum of the page. copy paste the link as new url and repeat the above steps.
# * Explain your reflection.
# * Do you find it any useful at all compared to using local data?

# %% [markdown]
#  ## 1.3. **metadata** (e.g. OGC records)

# %%
import requests  # Import the requests library

# Query URL
url = "https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items"
# Some api's will have nicer syntax like:
# `&time=2010..2012` or `&na_item=B1GQ,D21`
print(url)

response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
payload = response.json()  # Parse `response.text` into JSON

import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(payload)
# NOTE: Could use print(response.json()) but this wouldn't be formatted nicely
# Out:
# https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items
# Request returned 200 : 'OK'
# {   'features': [   {   'geometry': {   'coordinates': [   [   [31.5, 41.0],
#                                                                [39.0, 41.0],
#                                                                [39.0, 45.0],
#                                                                [31.5, 45.0],
#                                                                [31.5, 41.0]]],
#                                         'type': 'Polygon'},
#                         'id': '0f8ef991-67a0-43e6-9417-d03abd5f3a28',
#                         'links': [],
#                         'properties': {   'title': 'Black Sea Rim Current '
#                                                    'Intensity Index',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [27.0, 41.0],
#                                                                [42.0, 41.0],
#                                                                [42.0, 46.0],
#                                                                [27.0, 46.0],
#                                                                [27.0, 41.0]]],
#                                         'type': 'Polygon'},
#                         'id': '1ed72ba8-04c2-494c-90f0-dbc7a5a304de',
#                         'links': [],
#                         'properties': {   'title': 'High-resolution L3 Sea '
#                                                    'Surface Wind from NRT '
#                                                    'Satellite Measurements '
#                                                    'over the Black Sea',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [-20.0, 48.0],
#                                                                [13.0, 48.0],
#                                                                [13.0, 62.0],
#                                                                [-20.0, 62.0],
#                                                                [-20.0, 48.0]]],
#                                         'type': 'Polygon'},
#                         'id': '31cecaf4-2e37-45a4-9984-98c693c7afc7',
#                         'links': [],
#                         'properties': {   'title': 'North West Atlantic Shelf '
#                                                    'Mean Sea Level time series '
#                                                    'and trend from '
#                                                    'Observations Reprocessing',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [10.0, 54.0],
#                                                                [30.0, 54.0],
#                                                                [30.0, 66.0],
#                                                                [10.0, 66.0],
#                                                                [10.0, 54.0]]],
#                                         'type': 'Polygon'},
#                         'id': '3eeae078-76d8-412a-96e3-82b6b59396f7',
#                         'links': [],
#                         'properties': {   'title': 'High-resolution L3 Sea '
#                                                    'Surface Wind from NRT '
#                                                    'Satellite Measurements '
#                                                    'over the Baltic Sea',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [6.0, 30.18],
#                                                                [36.3, 30.18],
#                                                                [36.3, 45.98],
#                                                                [6.0, 45.98],
#                                                                [6.0, 30.18]]],
#                                         'type': 'Polygon'},
#                         'id': '3adfd383-abea-46ff-b691-d540830d3b97',
#                         'links': [],
#                         'properties': {   'title': 'Mediterranean Ocean Salt '
#                                                    'Content (0-300m)',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [-5.0, 30.0],
#                                                                [36.0, 30.0],
#                                                                [36.0, 46.0],
#                                                                [-5.0, 46.0],
#                                                                [-5.0, 30.0]]],
#                                         'type': 'Polygon'},
#                         'id': '54d8896a-9fa3-437f-adc0-1bed6100c074',
#                         'links': [],
#                         'properties': {   'title': 'High-resolution L3 Sea '
#                                                    'Surface Wind from NRT '
#                                                    'Satellite Measurements '
#                                                    'over the Mediterranean Sea',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [9.7, 52.0],
#                                                                [31.0, 52.0],
#                                                                [31.0, 66.0],
#                                                                [9.7, 66.0],
#                                                                [9.7, 52.0]]],
#                                         'type': 'Polygon'},
#                         'id': '69a6b688-f1d8-40c2-b420-e6234ff48b12',
#                         'links': [],
#                         'properties': {   'title': 'Baltic Sea Mean Sea Level '
#                                                    'time series and trend from '
#                                                    'Observations Reprocessing',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [-19.0, 26.0],
#                                                                [5.0, 26.0],
#                                                                [5.0, 56.0],
#                                                                [-19.0, 56.0],
#                                                                [-19.0, 26.0]]],
#                                         'type': 'Polygon'},
#                         'id': '53934c26-903f-4f0d-bf8b-abaf68f29256',
#                         'links': [],
#                         'properties': {   'title': 'Iberia Biscay Ireland Sea '
#                                                    'Surface Temperature trend '
#                                                    'map from Observations '
#                                                    'Reprocessing',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [-42.0, 62.0],
#                                                                [100.0, 62.0],
#                                                                [100.0, 85.0],
#                                                                [-42.0, 85.0],
#                                                                [-42.0, 62.0]]],
#                                         'type': 'Polygon'},
#                         'id': '5a514f24-22c4-4481-a4e8-8fe2a3b2bd56',
#                         'links': [],
#                         'properties': {   'title': 'High-resolution L3 Sea '
#                                                    'Surface Wind from NRT '
#                                                    'Satellite Measurements '
#                                                    'over the Arctic Sea',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'},
#                     {   'geometry': {   'coordinates': [   [   [-180.0, -90.0],
#                                                                [180.0, -90.0],
#                                                                [180.0, 90.0],
#                                                                [-180.0, 90.0],
#                                                                [   -180.0,
#                                                                    -90.0]]],
#                                         'type': 'Polygon'},
#                         'id': '15801dcd-7841-40cb-b2f6-97dfcfe1776d',
#                         'links': [],
#                         'properties': {   'title': 'Kuroshio Phase from '
#                                                    'Observations Reprocessing',
#                                           'type': 'series'},
#                         'time': None,
#                         'type': 'Feature'}],
#     'links': [   {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items?f=json&bbox=-25,27,43,72',
#                      'rel': 'self',
#                      'title': 'This document as GeoJSON',
#                      'type': 'application/geo+json'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items?f=jsonld&bbox=-25,27,43,72',
#                      'rel': 'alternate',
#                      'title': 'This document as RDF (JSON-LD)',
#                      'type': 'application/ld+json'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items?f=html&bbox=-25,27,43,72',
#                      'rel': 'alternate',
#                      'title': 'This document as HTML',
#                      'type': 'text/html'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items?offset=10&bbox=-25,27,43,72',
#                      'rel': 'next',
#                      'title': 'items (next)',
#                      'type': 'application/geo+json'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items',
#                      'rel': 'collection',
#                      'title': 'Copernicus Marine',
#                      'type': 'application/json'}],
#     'numberMatched': 269,
#     'timeStamp': '2026-01-14T09:30:18.797387Z',
#     'type': 'FeatureCollection'}

# %%
# see the metadata of first feature (item)
payload['features'][0]
# Out:
# {'id': '0f8ef991-67a0-43e6-9417-d03abd5f3a28',
#  'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[31.5, 41.0],
#     [39.0, 41.0],
#     [39.0, 45.0],
#     [31.5, 45.0],
#     [31.5, 41.0]]]},
#  'time': None,
#  'properties': {'type': 'series',
#   'title': 'Black Sea Rim Current Intensity Index'},
#  'links': []}

# %%
item_name = payload['features'][0]["id"]
url = url+"/"+item_name
print(url)
# Out:
# https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items/0f8ef991-67a0-43e6-9417-d03abd5f3a28

# %%
response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
payload = response.json()  # Parse `response.text` into JSON

import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(payload)
# Out:
# Request returned 200 : 'OK'
# {   'geometry': {   'coordinates': [   [   [31.5, 41.0],
#                                            [39.0, 41.0],
#                                            [39.0, 45.0],
#                                            [31.5, 45.0],
#                                            [31.5, 41.0]]],
#                     'type': 'Polygon'},
#     'id': '0f8ef991-67a0-43e6-9417-d03abd5f3a28',
#     'links': [   {   'description': 'For accessing native data and '
#                                     'Analysis-ready Cloud-optimized data '
#                                     'services, consult this STAC metadata '
#                                     'endpoint',
#                      'href': 'https://stac.marine.copernicus.eu/metadata/OMI_CIRCULATION_BOUNDARY_BLKSEA_rim_current_index/blksea_omi_circulation_rim_current_index_202311/dataset.stac.json',
#                      'name': 'blksea_omi_circulation_rim_current_index',
#                      'protocol': 'WWW:STAC',
#                      'rel': 'alternate',
#                      'title': 'blksea_omi_circulation_rim_current_index',
#                      'type': 'application/json',
#                      'url': 'https://stac.marine.copernicus.eu/metadata/OMI_CIRCULATION_BOUNDARY_BLKSEA_rim_current_index/blksea_omi_circulation_rim_current_index_202311/dataset.stac.json'},
#                  {   'description': None,
#                      'href': 'https://wmts.marine.copernicus.eu/teroWmts/OMI_CIRCULATION_BOUNDARY_BLKSEA_rim_current_index/blksea_omi_circulation_rim_current_index_202311?service=WTMS&request=GetCapabilities',
#                      'name': 'blksea_omi_circulation_rim_current_index',
#                      'protocol': 'OGC:WMTS',
#                      'rel': 'alternate',
#                      'title': 'blksea_omi_circulation_rim_current_index',
#                      'type': 'application/octet-stream',
#                      'url': 'https://wmts.marine.copernicus.eu/teroWmts/OMI_CIRCULATION_BOUNDARY_BLKSEA_rim_current_index/blksea_omi_circulation_rim_current_index_202311?service=WTMS&request=GetCapabilities'},
#                  {   'description': None,
#                      'href': 'https://catalogue.marine.copernicus.eu/documents/IMG/OMI_CIRCULATION_BOUNDARY_BLKSEA_rim_current_index.png',
#                      'name': None,
#                      'protocol': 'image/png',
#                      'rel': 'alternate',
#                      'title': None,
#                      'type': 'image/png',
#                      'url': 'https://catalogue.marine.copernicus.eu/documents/IMG/OMI_CIRCULATION_BOUNDARY_BLKSEA_rim_current_index.png'},
#                  {   'href': 'https://cmems-catalog-ro.cls.fr/geonetwork/srv/eng/csw-MYOCEAN-CORE-PRODUCTS?SERVICE=CSW&VERSION=2.0.2&REQUEST=GetRecordById&ElementSetName=full&Id=0f8ef991-67a0-43e6-9417-d03abd5f3a28',
#                      'rel': 'alternate',
#                      'title': 'Original metadata',
#                      'type': 'text/xml'},
#                  {   'href': 'https://s3.waw3-1.cloudferro.com/mdl-native-14/native/OMI_CIRCULATION_BOUNDARY_BLKSEA_rim_current_index/blksea_omi_circulation_rim_current_index_202311/blksea_omi_circulation_rim_current_index.nc',
#                      'rel': 'describes',
#                      'title': 'Native dataset',
#                      'type': 'application/x-netcdf'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir?f=json',
#                      'rel': 'root',
#                      'title': 'The landing page of this server as JSON',
#                      'type': 'application/json'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir?f=html',
#                      'rel': 'root',
#                      'title': 'The landing page of this server as HTML',
#                      'type': 'text/html'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items/0f8ef991-67a0-43e6-9417-d03abd5f3a28?f=json',
#                      'rel': 'self',
#                      'title': 'This document as GeoJSON',
#                      'type': 'application/geo+json'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items/0f8ef991-67a0-43e6-9417-d03abd5f3a28?f=jsonld',
#                      'rel': 'alternate',
#                      'title': 'This document as RDF (JSON-LD)',
#                      'type': 'application/ld+json'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine/items/0f8ef991-67a0-43e6-9417-d03abd5f3a28?f=html',
#                      'rel': 'alternate',
#                      'title': 'This document as HTML',
#                      'type': 'text/html'},
#                  {   'href': 'https://vm4072.kaj.pouta.csc.fi/ddas/oapir/collections/copernicusmarine',
#                      'rel': 'collection',
#                      'title': 'Copernicus Marine',
#                      'type': 'application/json'}],
#     'properties': {   'created': '2024-03-25T08:56:26.245Z',
#                       'description': "'''DEFINITION'''\n"
#                                      '\n'
#                                      'The Black Sea Rim Current index (BSRCI) '
#                                      'reflects the intensity of the Rim '
#                                      'current, which is a main feature of the '
#                                      'Black Sea circulation, a basin scale '
#                                      'cyclonic current. The index was computed '
#                                      'using sea surface current speed averaged '
#                                      'over two areas of intense currents based '
#                                      'on reanalysis data. The areas are '
#                                      'confined between the 200 and 1800 m '
#                                      'isobaths in the northern section 33-39E '
#                                      '(from the Caucasus coast to the Crimea '
#                                      'Peninsula), and in the southern section '
#                                      '31.5-35E (from Sakarya region to near '
#                                      'Sinop Peninsula). Thus, three indices '
#                                      'were defined: one for the northern '
#                                      'section (BSRCIn), for the southern '
#                                      'section (BSRCIs) and an average for the '
#                                      'entire basin (BSRCI).\n'
#                                      'BSRCI=(V ̅_ann-V ̅_cl)/V ̅_cl \n'
#                                      'where V ̅ denotes the representative '
#                                      'area average, the “ann” denotes the '
#                                      'annual mean for each individual year in '
#                                      'the analysis, and “cl” indicates the '
#                                      'long-term mean over the whole period '
#                                      '1993-2020. In general, BSRCI is defined '
#                                      'as the relative annual anomaly from the '
#                                      'long-term mean speed.  An index close to '
#                                      'zero means close to the average '
#                                      'conditions a positive index indicates '
#                                      'that the Rim current is more intense '
#                                      'than average, or negative - if it is '
#                                      'less intense than average. In other '
#                                      'words, positive BSRCI would mean higher '
#                                      'circumpolar speed, enhanced '
#                                      'baroclinicity, enhanced dispersion of '
#                                      'pollutants, less degree of exchange '
#                                      'between open sea and coastal areas, '
#                                      'intensification of the heat '
#                                      'redistribution, etc.\n'
#                                      'The BSRCI is introduced in the fifth '
#                                      'issue of the Ocean State Report (von '
#                                      'Schuckmann et al., 2021). The Black Sea '
#                                      'Physics Reanalysis '
#                                      '(BLKSEA_REANALYSIS_PHYS_007_004) has '
#                                      'been used as a data base to build the '
#                                      'index. Details on the products are '
#                                      'delivered in the PUM and QUID of this '
#                                      'OMI.\n'
#                                      '\n'
#                                      "'''CONTEXT'''\n"
#                                      '\n'
#                                      'The Black Sea circulation is driven by '
#                                      'the regional winds and large freshwater '
#                                      'river inflow in the north-western part '
#                                      '(including the main European rivers '
#                                      'Danube, Dnepr and Dnestr). The major '
#                                      'cyclonic gyre encompasses the sea, '
#                                      'referred to as Rim current. It is '
#                                      'quasi-geostrophic and the Sverdrup '
#                                      'balance approximately applies to it. \n'
#                                      'The Rim current position and speed '
#                                      'experiences significant interannual '
#                                      'variability (Stanev and Peneva, 2002), '
#                                      'intensifying in winter due to the '
#                                      'dominating severe northeastern winds in '
#                                      'the region (Stanev et al., 2000). '
#                                      'Consequently, this impacts the vertical '
#                                      'stratification, Cold Intermediate Water '
#                                      'formation, the biological activity '
#                                      'distribution and the coastal mesoscale '
#                                      'eddies’ propagation along the current '
#                                      'and their evolution. The higher '
#                                      'circumpolar speed leads to enhanced '
#                                      'dispersion of pollutants, less degree of '
#                                      'exchange between open sea and coastal '
#                                      'areas, enhanced baroclinicity, '
#                                      'intensification of the heat '
#                                      'redistribution which is important for '
#                                      'the winter freezing in the northern '
#                                      'zones (Simonov and Altman, 1991). Fach '
#                                      '(2015) finds that the anchovy larval '
#                                      'dispersal in the Black Sea is strongly '
#                                      'controlled at the basin scale by the Rim '
#                                      'Current and locally - by mesoscale '
#                                      'eddies. \n'
#                                      'Several recent studies of the Black Sea '
#                                      'pollution claim that the understanding '
#                                      'of the Rim Current behavior and how the '
#                                      'mesoscale eddies evolve would help to '
#                                      'predict the transport of various '
#                                      'pollution such as oil spills (Korotenko, '
#                                      '2018) and floating marine litter (Stanev '
#                                      'and Ricker, 2019) including microplastic '
#                                      'debris (Miladinova et al., 2020) raising '
#                                      'a serious environmental concern today. \n'
#                                      'To summarize, the intensity of the Black '
#                                      'Sea Rim Current could give valuable '
#                                      'integral measure for a great deal of '
#                                      'physical and biogeochemical processes '
#                                      'manifestation. Thus our objective is to '
#                                      'develop a comprehensive index reflecting '
#                                      'the annual mean state of the Black Sea '
#                                      'general circulation to be used by policy '
#                                      'makers and various end users. \n'
#                                      '\n'
#                                      "'''CMEMS KEY FINDINGS'''\n"
#                                      '\n'
#                                      'The Black Sea Rim Current Index is '
#                                      'defined as the relative annual anomaly '
#                                      'of the long-term mean speed. The BSRCI '
#                                      'value characterizes the annual '
#                                      'circulation state: a value close to zero '
#                                      'would mean close to average conditions, '
#                                      'positive value indicates enhanced '
#                                      'circulation, and negative value – weaker '
#                                      'circulation than usual. The time-series '
#                                      'of the BSRCI suggest that the Black Sea '
#                                      'Rim current speed varies within ~30% in '
#                                      'the period 1993-2020 with a positive '
#                                      'trend of ~0.1 m/s/decade. In the years '
#                                      '2005 and 2014 there is evidently higher '
#                                      'mean velocity, and on the opposite end '
#                                      'are the years –2004, 2013 and 2016. The '
#                                      'time series of the BSRCI gives '
#                                      'possibility to check the relationship '
#                                      'with the wind vorticity and validate the '
#                                      'Sverdrup balance hypothesis. \n'
#                                      '\n'
#                                      "'''Figure caption'''\n"
#                                      '\n'
#                                      'Time series of the Black Sea Rim Current '
#                                      'Index (BSRCI) at the north section '
#                                      '(BSRCIn), south section (BSRCIs), the '
#                                      'average (BSRCI) and its tendency for the '
#                                      'period 1993-2020.\n'
#                                      '\n'
#                                      "'''DOI (product):''' \n"
#                                      'https://doi.org/10.48670/mds-00326',
#                       'formats': 'NetCDF-4',
#                       'keywords': [   'Oceanographic geographical features',
#                                       'numerical-model',
#                                       'rim_current_intensity_index',
#                                       'multi-year',
#                                       'coastal-marine-environment',
#                                       'marine-safety',
#                                       'marine-resources',
#                                       'weather-climate-and-seasonal-forecasting',
#                                       'black-sea',
#                                       'N/A',
#                                       'Not Applicable',
#                                       'oceans'],
#                       'language': 'eng',
#                       'rights': ['otherRestrictions', 'license'],
#                       'title': 'Black Sea Rim Current Intensity Index',
#                       'type': 'series'},
#     'time': None,
#     'type': 'Feature'}

# %% [markdown]
# ### Advanced part 4: getting data within an spatial box or subset:
# In PyGeoApi, you can give bbox or subset of our area of interest, and it returns only that partm instead of reading (requesting) the whole data. All you need is to give bbox or subset as following to the end of url:
# ```
# &bbox=24,60,25,61
# ```
# if needed also add the crs of bbox```&bbox-crs=3857```
# For example in case of this example url:
#
# ```
# https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?f=GTiff
# ```
# we can add
#
# ```
# &bbox=24,60,25,61
# ```
#
# so it will be
#
#
# ```
# https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?f=GTiff&bbox=24,60,25,61
# ```
# and it will download that subset of the data via url requests.
#
# As you can see, the file size (when downloading) is smaller now, becuase we request subset of the data.
#
#
# ---
# ---
# > Another example:
#
# Another example can be the url that we were working already in our code above, which was:
#
# ```
# https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?f=GTiff
# ```
# we can add
#
# ```
# &subset=x(3034143:3035143),y(8782089:8792089)&scale-size=x(1000),y(1000)
# ```
#
# so it will be
#
#
# ```
# https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?f=GTiff&&subset=x(3034143:3035143),y(8782089:8792089)&scale-size=x(1000),y(1000)
# ```
# which finally will give you that subset of spatial area, with pixels scaled to 1000.
# > subset x (xmin to xmax)  y (ymin to ymax).
# > scale-size is the output pixels size. Do not make it so small pixel size for large areas. Server has specifications to avoid too large requests.
#
#
# Please read more examples in https://docs.pygeoapi.io/en/latest/publishing/ogcapi-coverages.html#data-access-examples

# %%
import rasterio
url_with_bbox = "https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?f=GTiff&&subset=x(3033143:3034143),y(8782089:8783089)&scale-size=x(1000),y(1000)"
raster_with_bbox = rasterio.open(url_with_bbox)

# %%
import matplotlib.pyplot as plt
show(raster_with_bbox)
# Out:
# <Axes: >

# %%
import leafmap
m = leafmap.Map()
m.add_cog_layer(url_with_bbox, name="Corine Land cover")
#m.zoom_to_bounds(raster_with_bbox.bounds)
m
# Out:
# Map(center=[27.251678734621972, 61.67543185629897], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
with rasterio.open(url_with_bbox) as ds:
    raster = ds.read(1)  # read first band
    transform = ds.transform
    crs = ds.crs

# %%
import numpy as np

# Mask nodata values if they exist
if ds.nodata is not None:
    raster = np.ma.masked_equal(raster, ds.nodata)

# Compute histogram
hist, bin_edges = np.histogram(raster.compressed(), bins=256)  # compressed() removes masked nodata

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot raster
show(raster_with_bbox, ax=ax1, cmap='viridis')
ax1.set_title("Raster")

# Plot histogram
ax2.bar(bin_edges[:-1], hist, width=np.diff(bin_edges), color='gray', edgecolor='black')
ax2.set_title("Histogram of pixel values")
ax2.set_xlabel("Pixel value")
ax2.set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
##### bbox in GTiff NEW NEW

url = 'https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?f=GTiff'


params = {
    "bbox": "2600000,8800000,3000000,9000000",  # minx,miny,maxx,maxy
    #"bbox-crs": "http://www.opengis.net/def/crs/EPSG/0/4326",
    #"f": "GTiff"
}

r = requests.get(url, params=params)

with open("output.tif", "wb") as f:
    f.write(r.content)

# %%
x = requests.get("https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/h90m_segment4326/coverage?subset=x(-46.33988358528477:64.30988358528478),y(30.75306162442881:73.70866809709719)")

# %%
# !ls -l
# Out:
# total 136
# -rw-r--r-- 1 root root 131072 Jan 14 07:35 dataframe_gdf_converted.gpkg
# -rw-r--r-- 1 root root     68 Jan 14 07:51 output.tif
# drwxr-xr-x 1 root root   4096 Dec 11 14:34 sample_data

# %% [markdown]
# ## ***1.4 [bonus] Other useful info***
# This section is meant just ofr extra bonus. Doing it is just optional.

# %% [markdown]
# ### 1.4.1 reading webmapservice (WMS)

# %%
import requests

wms_url = 'https://vm4072.kaj.pouta.csc.fi/ddas/oapic/collections/clc_clcplus3857-2018/coverage?f=GTiff&subset=x(-5158532.244133477:7158943.493688605),y(3600720.848604912:12398917.804192113)&scale-size=x(514.4000000000001),y(798.4000000000001)'


r = requests.get(wms_url, timeout=30)

print("status:", r.status_code)
print("content-type:", r.headers.get("Content-Type"))
print(r.text[:300])

# %%
from owslib.wms import WebMapService

wms = WebMapService(wms_url, version="1.3.0")
print(list(wms.contents))

# %%
from rasterio import MemoryFile
from rasterio.plot import show

request = wms.getmap(
    #layers=['CGS_S2_RADIOMETRY'],
    #srs='EPSG:3857',
    #format='image/png',
    bbox=(556945.9710290054,6657998.9149440415,575290.8578174476,6663655.255037144),
    #size=(1920,592),
    #time='2020-06-01'
)

with MemoryFile(request) as memfile:
     with memfile.open() as dataset:
            show(dataset)

# %% [markdown]
# ### 1.4.2 applying filters in geopandas gdf

# %%
# Remove bad geometries if needed
gdf = gdf[gdf.geometry.notnull()]
gdf = gdf[gdf.is_valid]
gdf = gdf[~gdf.geometry.is_empty]

# Print bounds
print("Bounds:", gdf.total_bounds)

# %% [markdown]
# ### 1.4.3. Loading data from local zip directly via geopandas

# %%
## FYI: you can load ZIP files that contain your locla data also directly via geopandas:
##zipfile = "zip:///path/to/your/files/example.zip"
##file = geopandas.read_file(zipfile)

# %%
### FYI: plotting other api's raster interactively and directly on leafmap
#m = leafmap.Map()
#url = "https://opendata.digitalglobe.com/events/california-fire-2020/pre-event/2018-02-16/pine-gulch-fire20/1030010076004E00.tif"
#m.add_cog_layer(url, name="Fire (pre-event)")
#m
